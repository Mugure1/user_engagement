# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read data
userActivity=pd.read_csv("C:/Users/acer/Desktop/projects/user engagement/UserActivity.csv")
users=pd.read_csv("C:/Users/acer/Desktop/projects/user engagement/Users.csv")
blogs=pd.read_csv("C:/Users/acer/Desktop/projects/user engagement/Blogs.csv")
comments=pd.read_csv("C:/Users/acer/Desktop/projects/user engagement/Comments.csv")
competition=pd.read_csv("C:/Users/acer/Desktop/projects/user engagement/Competition.csv")
compe_participation=pd.read_csv("C:/Users/acer/Desktop/projects/user engagement/CompetitionPartipation.csv")
dicussion=pd.read_csv("C:/Users/acer/Desktop/projects/user engagement/Discussion.csv")
jobs=pd.read_csv("C:/Users/acer/Desktop/projects/user engagement/Jobs.csv")
samplesub=pd.read_csv("C:/Users/acer/Desktop/projects/user engagement/SampleSubmission.csv")

# %%
jobs.head()
# Out:
#   Remote Experience                                  Industry Employment Type  \
# 0    NaN        2-5  {Government,Health,"Financial Services"}        fulltime
# 1    NaN        NaN                                       NaN             NaN
# 2   True         >5                                       NaN        fulltime
# 3    NaN         >5                                   {Media}        fulltime
# 4    NaN        1-2                                   {Media}        fulltime
#
#   Company Size                             Data Science Functions   job_ID
# 0       50-200        {"Data modelling","Business/Data Analysis"}  ID_VJ43
# 1          NaN                                                NaN  ID_ZNZV
# 2         >200              {"Data engineering","Data modelling"}  ID_PZHM
# 3         1-10                               {"Data engineering"}  ID_1PBU
# 4         1-10  {"Data engineering","Data modelling","ML Appli...  ID_ZTPN

# %%
competition.head()
# Out:
#   FeatureA FeatureB  FeatureC  FeatureD  FeatureE  SecretCode FeatureF  \
# 0   [2, 4]     [14]      15.0         0         2           1      [3]
# 1      [1]       []       3.0         0         3           1      [1]
# 2      [1]      [9]       2.0         0         2           1   [1, 5]
# 3       []       []       1.0         0         2           1      [1]
# 4       []      [6]       NaN         0         2           0       []
#
#   FeatureG FeatureH  FeatureI Country_ID  Comp_ID End Time time  \
# 0       []       []       NaN       G3F0  ID_AU0T      21:05:00
# 1       []      [1]       3.0       0Q35  ID_O21T      15:30:00
# 2      [5]      [1]       2.0       EGI9  ID_W6XE      21:59:00
# 3      [4]       []       NaN        NaN  ID_A2FN      12:00:00
# 4      [4]      [2]       9.0        NaN  ID_X0PD      23:59:00
#
#    End Time Year  End Time Month  End Time Day_of_month Start Time time  \
# 0            2.0             6.0                   19.0        07:00:00
# ...

# %%
compe_participation.head()
# Out:
#   Competition ID  Participant Type Successful Submission Count      User_ID  \
# 0        ID_WPP3                 1                         NaN  ID_40G01FGV
# 1        ID_ZN92                 1                         NaN  ID_40G01FGV
# 2        ID_I9BN                 1                         NaN  ID_40G01FGV
# 3        ID_PDKH                 1                    count 10  ID_40G01FGV
# 4        ID_CFN7                 1                         NaN  ID_P33ABQX5
#
#    Created At time  Created At Year  Created At Month  Created At Day_of_month
# 0  19:38:04.689865                1                11                       20
# 1  19:38:04.670583                1                11                       20
# 2  12:06:55.884320                1                12                       17
# 3  11:24:04.239058                1                12                        6
# 4  05:16:09.052129                1                 5                       26

# %%
dicussion.head()
# Out:
#       Competition ID  Personal  Theme    Disc_ID      User_ID  \
# 0  GeneralDiscussion         1    NaN  ID_0BK7TH  ID_AAGFVLHH
# 1  GeneralDiscussion         1    NaN  ID_ZFJ9J7  ID_0AJGQILU
# 2  GeneralDiscussion         1    NaN  ID_ME45XX  ID_U90KK6KL
# 3            ID_45W9         1    NaN  ID_2BG9IX  ID_U90KK6KL
# 4  GeneralDiscussion         1    NaN  ID_251XVV  ID_F7HIGFHQ
#
#    Created At time  Created At Year  Created At Month  Created At Day_of_month
# 0  19:48:26.862175                1                12                       27
# 1  09:37:52.039526                1                12                       20
# 2  17:50:33.894800                1                 2                        9
# 3  07:57:55.178845                1                 2                       10
# 4  19:56:13.041893                1                12                       27

# %%
userActivity.head()
# Out:
#        User_ID         Title datetime time  datetime Year  datetime Month  \
# 0  ID_RT43AK77  comp_ID_IV5D      22:00:38              1              11
# 1  ID_RT43AK77  comp_ID_IV5D      00:41:02              1              11
# 2  ID_RT43AK77  comp_ID_IV5D      00:53:15              1              11
# 3  ID_RT43AK77  comp_ID_IV5D      01:23:05              1              11
# 4  ID_RT43AK77  comp_ID_IV5D      01:27:38              1              11
#
#    datetime Day_of_month
# 0                     22
# 1                     23
# 2                     23
# 3                     23
# 4                     23

# %%
comments.head()
# Out:
#      Disc_ID      User_ID  Created At time  Created At Year  Created At Month  \
# 0  ID_ONQEAR  ID_CEDNKSVV  16:18:44.841697                1                 5
# 1  ID_E0NHSS  ID_CEDNKSVV  17:30:40.566763                1                12
# 2  ID_3XKIOF  ID_CEDNKSVV  13:28:47.950841                1                 1
# 3  ID_XCC6W4  ID_CEDNKSVV  18:42:17.362333                1                 1
# 4  ID_OIGXGK  ID_CEDNKSVV  18:57:54.540062                1                12
#
#    Created At Day_of_month
# 0                       11
# 1                       23
# 2                        3
# 3                        5
# 4                       19

# %%
users.head()
# Out:
#    FeatureX  FeatureY      User_ID Countries_ID  Created At time  \
# 0         0         0  ID_DC6S4E9O         X9GR  19:33:13.663391
# 1         1         0  ID_E8S97OUT         X9GR  22:18:18.228921
# 2         0         0  ID_QZ1HASL3         X9GR  23:13:03.266635
# 3         1         0  ID_SDV9Q3E9         X9GR  09:50:09.697573
# 4         1         0  ID_W942LN7F         X9GR  13:33:06.531662
#
#    Created At Year  Created At Month  Created At Day_of_month
# 0                1                 1                       16
# 1                1                12                       27
# 2                1                 1                        1
# 3                1                12                       27
# 4                1                 1                       16

# %%
blogs.head()
# Out:
#    Theme  blog_ID Published At time  Published At Year  Published At Month  \
# 0    5.0  ID_Z6MM   10:34:55.071854                  5                   4
# 1    5.0  ID_7IB3   14:51:13.268049                  5                   4
# 2    3.0  ID_JR8K   13:19:08.877076                  5                   4
# 3    2.0  ID_IDAV   17:18:06.151314                  5                   7
# 4    2.0  ID_7JVL   11:48:36.428428                  4                   8
#
#    Published At Day_of_month
# 0                          5
# 1                          5
# 2                         17
# 3                          6
# 4                         25

# %%
users.describe()
# Out:
#            FeatureX      FeatureY  Created At Year  Created At Month  \
# count  12413.000000  12413.000000          12413.0      12413.000000
# mean       0.085314      0.528237              1.0          5.258922
# std        0.279359      0.891619              0.0          3.970421
# min        0.000000      0.000000              1.0          1.000000
# 25%        0.000000      0.000000              1.0          2.000000
# 50%        0.000000      0.000000              1.0          4.000000
# 75%        0.000000      1.000000              1.0         11.000000
# max        1.000000      3.000000              1.0         12.000000
#
#        Created At Day_of_month
# count             12413.000000
# mean                 16.305970
# std                   9.023629
# min                   1.000000
# 25%                   8.000000
# 50%                  17.000000
# 75%                  25.000000
# max                  31.000000

# %%
userActivity.describe()
# Out:
#        datetime Year  datetime Month  datetime Day_of_month
# count       317292.0   317292.000000          317292.000000
# mean             1.0        4.462274              16.135462
# std              0.0        3.660884               8.890560
# min              1.0        1.000000               1.000000
# 25%              1.0        2.000000               8.000000
# 50%              1.0        3.000000              16.000000
# 75%              1.0        5.000000              24.000000
# max              1.0       12.000000              31.000000

# %%
users.isnull().sum()*100/len(users)
# Out:
# FeatureX                    0.000000
# FeatureY                    0.000000
# User_ID                     0.000000
# Countries_ID               47.385805
# Created At time             0.000000
# Created At Year             0.000000
# Created At Month            0.000000
# Created At Day_of_month     0.000000
# dtype: float64

# %%
users.drop(['Countries_ID','Created At time'],axis=1,inplace=True)

# %%
comments.isnull().sum()*100/len(comments)
# Out:
# Disc_ID                    0.0
# User_ID                    0.0
# Created At time            0.0
# Created At Year            0.0
# Created At Month           0.0
# Created At Day_of_month    0.0
# dtype: float64

# %%
comments.drop(['Created At time'],axis=1,inplace=True)

# %%
compe_participation.isnull().sum()*100/len(compe_participation)
# Out:
# Competition ID                  0.000000
# Participant Type                0.000000
# Successful Submission Count    82.719141
# User_ID                         0.000000
# Created At time                 0.000000
# Created At Year                 0.000000
# Created At Month                0.000000
# Created At Day_of_month         0.000000
# dtype: float64

# %%
compe_participation.drop(['Successful Submission Count','Created At time'],axis=1,inplace=True)

# %%
competition.isnull().sum()*100/len(competition)
# Out:
# FeatureA                    0.000000
# FeatureB                    0.000000
# FeatureC                   20.647773
# FeatureD                    0.000000
# FeatureE                    0.000000
# SecretCode                  0.000000
# FeatureF                    0.000000
# FeatureG                    0.000000
# FeatureH                    0.000000
# FeatureI                   24.696356
# Country_ID                 51.012146
# Comp_ID                     0.000000
# End Time time               9.311741
# End Time Year               9.311741
# End Time Month              9.311741
# End Time Day_of_month       9.311741
# Start Time time             0.000000
# Start Time Year             0.000000
# Start Time Month            0.000000
# Start Time Day_of_month     0.000000
# dtype: float64

# %%
competition.drop(['FeatureC','FeatureI','Country_ID'],axis=1,inplace=True)

# %%
dicussion.isnull().sum()*100/len(dicussion)
# Out:
# Competition ID              0.00000
# Personal                    0.00000
# Theme                      88.95066
# Disc_ID                     0.00000
# User_ID                     0.00000
# Created At time             0.00000
# Created At Year             0.00000
# Created At Month            0.00000
# Created At Day_of_month     0.00000
# dtype: float64

# %%
dicussion.drop(['Theme','Created At time'],axis=1,inplace=True)

# %%
competition.describe()
# Out:
#          FeatureD    FeatureE  SecretCode  End Time Year  End Time Month  \
# count  247.000000  247.000000  247.000000     224.000000      224.000000
# mean     0.461538    2.170040    0.433198      11.138393        6.031250
# std      0.499531    0.544217    0.496524     135.029289        3.554055
# min      0.000000    1.000000    0.000000       1.000000        1.000000
# 25%      0.000000    2.000000    0.000000       1.000000        3.000000
# 50%      0.000000    2.000000    0.000000       2.000000        5.000000
# 75%      1.000000    2.000000    1.000000       3.000000        9.250000
# max      1.000000    3.000000    1.000000    2023.000000       12.000000
#
#        End Time Day_of_month  Start Time Year  Start Time Month  \
# count             224.000000       247.000000        247.000000
# mean               17.892857         2.319838          5.789474
# std                 8.947638         1.073958          3.597115
# ...

# %%
compe_participation.describe()
# Out:
#        Participant Type  Created At Year  Created At Month  \
# count            8385.0           8385.0       8385.000000
# mean                1.0              1.0          4.759332
# std                 0.0              0.0          3.750514
# min                 1.0              1.0          1.000000
# 25%                 1.0              1.0          2.000000
# 50%                 1.0              1.0          3.000000
# 75%                 1.0              1.0          5.000000
# max                 1.0              1.0         12.000000
#
#        Created At Day_of_month
# count              8385.000000
# mean                 16.394037
# std                   8.994738
# min                   1.000000
# 25%                   8.000000
# 50%                  17.000000
# 75%                  25.000000
# max                  31.000000

# %%
dicussion.describe()
# Out:
#           Personal  Created At Year  Created At Month  Created At Day_of_month
# count  1439.000000           1439.0       1439.000000              1439.000000
# mean      0.805420              1.0          4.013204                15.780403
# std       0.396014              0.0          3.350082                 9.212022
# min       0.000000              1.0          1.000000                 1.000000
# 25%       1.000000              1.0          2.000000                 7.000000
# 50%       1.000000              1.0          3.000000                15.000000
# 75%       1.000000              1.0          5.000000                24.000000
# max       1.000000              1.0         12.000000                31.000000

# %%
usersfinal=pd.merge(users,userActivity,on='User_ID',how='outer')

# %%
usersfinal.describe()
# Out:
#             FeatureX       FeatureY  Created At Year  Created At Month  \
# count  319305.000000  319305.000000         319305.0     319305.000000
# mean        0.224585       0.403583              1.0          5.669235
# std         0.417309       0.794609              0.0          4.355757
# min         0.000000       0.000000              1.0          1.000000
# 25%         0.000000       0.000000              1.0          2.000000
# 50%         0.000000       0.000000              1.0          4.000000
# 75%         0.000000       1.000000              1.0         11.000000
# max         1.000000       3.000000              1.0         12.000000
#
#        Created At Day_of_month  datetime Year  datetime Month  \
# count            319305.000000       317292.0   317292.000000
# mean                 16.478170            1.0        4.462274
# std                   8.756468            0.0        3.660884
# min                   1.000000            1.0        1.000000
# ...

# %%
usersfinal.drop(['datetime Year'],axis=1,inplace=True)

# %%
usersfinal.describe()
# Out:
#             FeatureX       FeatureY  Created At Year  Created At Month  \
# count  319305.000000  319305.000000         319305.0     319305.000000
# mean        0.224585       0.403583              1.0          5.669235
# std         0.417309       0.794609              0.0          4.355757
# min         0.000000       0.000000              1.0          1.000000
# 25%         0.000000       0.000000              1.0          2.000000
# 50%         0.000000       0.000000              1.0          4.000000
# 75%         0.000000       1.000000              1.0         11.000000
# max         1.000000       3.000000              1.0         12.000000
#
#        Created At Day_of_month  datetime Month  datetime Day_of_month
# count            319305.000000   317292.000000          317292.000000
# mean                 16.478170        4.462274              16.135462
# std                   8.756468        3.660884               8.890560
# ...

# %%
np.unique(usersfinal[['Created At Month']].values)
# Out:
# array([ 1,  2,  3,  4,  5, 11, 12], dtype=int64)

# %%
np.unique(usersfinal[['datetime Month']].values)
# Out:
# array([ 1.,  2.,  3.,  4.,  5., 11., 12., nan])

# %% [markdown]
# #my target variable is datetime Month where user_ID with values are train datasets and those with null are test sets after split

# %%
usersfinal.isnull().sum()*100/len(usersfinal)
# Out:
# FeatureX                   0.000000
# FeatureY                   0.000000
# User_ID                    0.000000
# Created At Year            0.000000
# Created At Month           0.000000
# Created At Day_of_month    0.000000
# Title                      0.630432
# datetime time              0.630432
# datetime Month             0.630432
# datetime Day_of_month      0.630432
# dtype: float64

# %%
usersfinal.tail(15)
# Out:
#         FeatureX  FeatureY      User_ID  Created At Year  Created At Month  \
# 319290         0         0  ID_XZS1QE0W                1                 5
# 319291         0         0  ID_XZS1QE0W                1                 5
# 319292         0         0  ID_XZS1QE0W                1                 5
# 319293         0         0  ID_XZS1QE0W                1                 5
# 319294         0         0  ID_XZS1QE0W                1                 5
# 319295         0         1  ID_8K4FGJYO                1                12
# 319296         0         1  ID_8K4FGJYO                1                12
# 319297         0         1  ID_8K4FGJYO                1                12
# 319298         0         1  ID_8K4FGJYO                1                12
# 319299         0         1  ID_8K4FGJYO                1                12
# 319300         0         1  ID_8K4FGJYO                1                12
# ...

# %%
usersfinal['Created At Month'].describe()
# Out:
# count    319305.000000
# mean          5.669235
# std           4.355757
# min           1.000000
# 25%           2.000000
# 50%           4.000000
# 75%          11.000000
# max          12.000000
# Name: Created At Month, dtype: float64

# %%
usersfinal.rename(columns={'Created At Month':'createdmonth','datetime Month':'datemonth'},inplace=True)

# %%
#a function for creating column target with values True, False AND NA where: the user had activity the consecutive months after use, no activity after they created the following month and na for missing values for activity which will be my test respectively
def createtarget(usersfinal,createdmonth,datemonth):
    usersfinal['target']=usersfinal.apply(lambda x:1 if(x['createdmonth']==12)&(x['datemonth']==1)else(x['createdmonth'])<(x['datemonth'])if pd.notna(x['datemonth'])else pd.NaT,axis=1)
    return usersfinal

# %%
usersfinal1=createtarget(usersfinal,'createdmonth','datetime Month')

# %%
usersfinal1.head()
# Out:
#    FeatureX  FeatureY      User_ID  Created At Year  createdmonth  \
# 0         0         0  ID_DC6S4E9O                1             1
# 1         0         0  ID_DC6S4E9O                1             1
# 2         0         0  ID_DC6S4E9O                1             1
# 3         0         0  ID_DC6S4E9O                1             1
# 4         0         0  ID_DC6S4E9O                1             1
#
#    Created At Day_of_month                   Title datetime time  datemonth  \
# 0                       16            blog_ID_TTTU      20:15:58        4.0
# 1                       16               Signed Up      20:33:13        1.0
# 2                       16           $create_alias      20:33:14        1.0
# 3                       16               $identify      20:33:14        1.0
# 4                       16  Viewed All Discussions      20:33:14        1.0
#
#    datetime Day_of_month target
# 0                   17.0   True
# 1                   16.0  False
# ...

# %%
usersfinal1.tail()
# Out:
#         FeatureX  FeatureY      User_ID  Created At Year  createdmonth  \
# 319300         0         1  ID_8K4FGJYO                1            12
# 319301         0         1  ID_8K4FGJYO                1            12
# 319302         0         1  ID_8K4FGJYO                1            12
# 319303         0         1  ID_8K4FGJYO                1            12
# 319304         0         1  ID_8K4FGJYO                1            12
#
#         Created At Day_of_month                   Title datetime time  \
# 319300                        5  Viewed All Discussions      11:22:55
# 319301                        5         Confirmed Email      11:23:01
# 319302                        5         Updated Profile      11:23:11
# 319303                        5         Updated Profile      11:23:42
# 319304                        5              badge_OCZE      09:37:07
#
#         datemonth  datetime Day_of_month target
# 319300       12.0                    5.0  False
# ...

# %%
usersfinal1['target'].value_counts(normalize=False,dropna=False)#check for the value counts in target column
# Out:
# False    250443
# True      66849
# NaT        2013
# Name: target, dtype: int64

# %%
usersfinal1['target'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
usersfinal1['target'].replace({'False':0,'True':1,'NaT':-1},inplace=True)

# %%
usersfinal1.head()
# Out:
#    FeatureX  FeatureY      User_ID  Created At Year  createdmonth  \
# 0         0         0  ID_DC6S4E9O                1             1
# 1         0         0  ID_DC6S4E9O                1             1
# 2         0         0  ID_DC6S4E9O                1             1
# 3         0         0  ID_DC6S4E9O                1             1
# 4         0         0  ID_DC6S4E9O                1             1
#
#    Created At Day_of_month                   Title datetime time  datemonth  \
# 0                       16            blog_ID_TTTU      20:15:58        4.0
# 1                       16               Signed Up      20:33:13        1.0
# 2                       16           $create_alias      20:33:14        1.0
# 3                       16               $identify      20:33:14        1.0
# 4                       16  Viewed All Discussions      20:33:14        1.0
#
#    datetime Day_of_month target
# 0                   17.0   True
# 1                   16.0  False
# ...

# %%
usersfinal1['Title'].value_counts()
# Out:
# Viewed All Competitions            58176
# Viewed All Discussions             47172
# Viewed All Learning Pages          22930
# Downloaded Competition Datafile    19578
# Updated Profile                    14748
#                                    ...
# blog_ID_22WI                           1
# comp_ID_C8Q1                           1
# blog_ID_IDAV                           1
# blog_ID_406V                           1
# blog_ID_WOOH                           1
# Name: Title, Length: 397, dtype: int64

# %%
# lets reduce the types of activities by removing the ids from them
usersfinal1.Title.str.replace("(ID).*",'')
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_4420\3981452166.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   usersfinal1.Title.str.replace("(ID).*",'')
# 0                          blog_
# 1                      Signed Up
# 2                  $create_alias
# 3                      $identify
# 4         Viewed All Discussions
#                    ...
# 319300    Viewed All Discussions
# 319301           Confirmed Email
# 319302           Updated Profile
# 319303           Updated Profile
# 319304                badge_OCZE
# Name: Title, Length: 319305, dtype: object

# %%
usersfinal1['Title'].value_counts()
# Out:
# Viewed All Competitions            58176
# Viewed All Discussions             47172
# Viewed All Learning Pages          22930
# Downloaded Competition Datafile    19578
# Updated Profile                    14748
#                                    ...
# blog_ID_22WI                           1
# comp_ID_C8Q1                           1
# blog_ID_IDAV                           1
# blog_ID_406V                           1
# blog_ID_WOOH                           1
# Name: Title, Length: 397, dtype: int64

# %%
allusers.isnull().sum()
# Out:
# FeatureX                   0
# FeatureY                   0
# User_ID                    0
# Created At Year            0
# createdmonth               0
# Created At Day_of_month    0
# Title                      0
# datetime time              0
# datemonth                  0
# datetime Day_of_month      0
# target                     0
# dtype: int64

# %%
users5=usersfinal1.loc[pd.isna(usersfinal1['target'])]
allusers=usersfinal1.loc[~pd.isna(usersfinal1['target'])]

# %%
def remove_id(x):
    x = x.replace('$', '')
    if 'ID' in x:
        x = "_".join(x.split('_')[:-1])
    x = x.replace(' ', '_')
    return x

allusers['Title'].apply(remove_id)
print(allusers['Title'].value_counts())
# Out:
# Viewed All Competitions            58176
# Viewed All Discussions             47172
# Viewed All Learning Pages          22930
# Downloaded Competition Datafile    19578
# Updated Profile                    14748
#                                    ...
# blog_ID_22WI                           1
# comp_ID_C8Q1                           1
# blog_ID_IDAV                           1
# blog_ID_406V                           1
# blog_ID_WOOH                           1
# Name: Title, Length: 397, dtype: int64

# %%
allusers.Title.str.replace("(ID).*",'')
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_4420\1615526859.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   allusers.Title.str.replace("(ID).*",'')
# 0                          blog_
# 1                      Signed Up
# 2                  $create_alias
# 3                      $identify
# 4         Viewed All Discussions
#                    ...
# 319300    Viewed All Discussions
# 319301           Confirmed Email
# 319302           Updated Profile
# 319303           Updated Profile
# 319304                badge_OCZE
# Name: Title, Length: 317292, dtype: object

# %%
allusers['Title'].value_counts()
# Out:
# Viewed All Competitions            58176
# Viewed All Discussions             47172
# Viewed All Learning Pages          22930
# Downloaded Competition Datafile    19578
# Updated Profile                    14748
#                                    ...
# blog_ID_22WI                           1
# comp_ID_C8Q1                           1
# blog_ID_IDAV                           1
# blog_ID_406V                           1
# blog_ID_WOOH                           1
# Name: Title, Length: 397, dtype: int64

# %%
#remove ids in title values
def remove_id(x):
    x = x.replace('$', '')
    if 'ID' in x:
        return "_".join(x.split('_')[:-1])
    
    return x.replace(' ', '_')

allusers.Title.apply(remove_id).value_counts()
# Out:
# Viewed_All_Competitions                 58176
# comp_ID                                 55540
# Viewed_All_Discussions                  47172
# Viewed_All_Learning_Pages               22930
# Downloaded_Competition_Datafile         19578
# Updated_Profile                         14748
# Created_Submission                      13649
# identify                                12339
# Signed_Up                               10862
# create_alias                             9346
# badge_OCZE                               8864
# Confirmed_Email                          8818
# Updated_Discussion                       6498
# Joined_Competition                       6086
# Viewed_All_Jobs                          4139
# Signed_In                                4100
# Updated_Submission                       2929
# blog_ID                                  2712
# badge_HYIO                               1760
# Signed_Out                               1660
# ...

# %%
allusers['main_activities'] = allusers.Title.apply(remove_id)
allusers.main_activities.unique()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_4420\1919135992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allusers['main_activities'] = allusers.Title.apply(remove_id)
# array(['blog_ID', 'Signed_Up', 'create_alias', 'identify',
#        'Viewed_All_Discussions', 'Viewed_All_Learning_Pages',
#        'badge_OCZE', 'Confirmed_Email', 'comp_ID', 'job_ID',
#        'Viewed_All_Competitions', 'Updated_Profile', 'Viewed_All_Jobs',
#        'Signed_In', 'Joined_Competition',
#        'Downloaded_Competition_Datafile', 'Created_Submission',
#        'Updated_Submission', 'Updated_Discussion', 'Viewed_FAQ',
#        'Invited_Member_To_Team', 'Joined_Team', 'Viewed_Discussion',
# ...

# %%
act_vc = allusers.main_activities.value_counts()
selected_activities = act_vc[act_vc > 1000].keys()
selected_activities
# Out:
# Index(['Viewed_All_Competitions', 'comp_ID', 'Viewed_All_Discussions',
#        'Viewed_All_Learning_Pages', 'Downloaded_Competition_Datafile',
#        'Updated_Profile', 'Created_Submission', 'identify', 'Signed_Up',
#        'create_alias', 'badge_OCZE', 'Confirmed_Email', 'Updated_Discussion',
#        'Joined_Competition', 'Viewed_All_Jobs', 'Signed_In',
#        'Updated_Submission', 'blog_ID', 'badge_HYIO', 'Signed_Out', 'job_ID',
#        'Viewed_Discussion'],
#       dtype='object')

# %%
allusers = allusers[allusers.main_activities.isin(selected_activities)].reset_index(drop=True)
allusers
# Out:
#         FeatureX  FeatureY      User_ID  Created At Year  createdmonth  \
# 0              0         0  ID_DC6S4E9O                1             1
# 1              0         0  ID_DC6S4E9O                1             1
# 2              0         0  ID_DC6S4E9O                1             1
# 3              0         0  ID_DC6S4E9O                1             1
# 4              0         0  ID_DC6S4E9O                1             1
# ...          ...       ...          ...              ...           ...
# 314600         0         1  ID_8K4FGJYO                1            12
# 314601         0         1  ID_8K4FGJYO                1            12
# 314602         0         1  ID_8K4FGJYO                1            12
# 314603         0         1  ID_8K4FGJYO                1            12
# 314604         0         1  ID_8K4FGJYO                1            12
#
#         Created At Day_of_month                   Title datetime time  \
# ...

# %%
# aggregate the number of times that a user has taken per month for each type of activities
dataset = allusers.groupby(['User_ID', 'main_activities', 'datemonth','target']).size().reset_index().\
    rename(columns={0: 'count'}).\
        sort_values(['User_ID', 'datemonth', 'count'], ascending=False)
dataset
# Out:
#             User_ID                  main_activities  datemonth  target  count
# 111314  ID_ZZVUJ45W  Downloaded_Competition_Datafile        3.0   False      3
# 111318  ID_ZZVUJ45W           Viewed_All_Discussions        3.0   False      2
# 111313  ID_ZZVUJ45W                  Confirmed_Email        3.0   False      1
# 111315  ID_ZZVUJ45W               Joined_Competition        3.0   False      1
# 111316  ID_ZZVUJ45W                        Signed_Up        3.0   False      1
# ...             ...                              ...        ...     ...    ...
# 1       ID_000H9XOP          Viewed_All_Competitions        5.0   False      1
# 2       ID_000H9XOP           Viewed_All_Discussions        5.0   False      1
# 3       ID_000H9XOP                          comp_ID        5.0   False      1
# 4       ID_000H9XOP                     create_alias        5.0   False      1
# 5       ID_000H9XOP                         identify        5.0   False      1
#
# ...

# %%
dataset.User_ID.nunique(), dataset[dataset['datemonth'] == 5].User_ID.nunique(),  samplesub.User_ID_Next_month_Activity.nunique()
# Out:
# (10400, 2203, 1340)

# %%
dataplot = sns.heatmap(allusers.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %%
Selected_users = dataset[['User_ID']].drop_duplicates().reset_index(drop=True)
# add ids from SampleSubmission file that are not in the Selected users
# Selected_users = Selected_users.append(pd.DataFrame(SampleSubmission.User_ID_Next_month_Activity.str.replace('_Month_5', '').unique(), columns=['User_ID']), ignore_index=True)
Selected_users
# Out:
#            User_ID
# 0      ID_ZZVUJ45W
# 1      ID_ZZUNZJ2U
# 2      ID_ZZQK0LU6
# 3      ID_ZZMHNLNT
# 4      ID_ZZJKFBR5
# ...            ...
# 10395  ID_00ETFE7J
# 10396  ID_008D2J6C
# 10397  ID_004UKSJV
# 10398  ID_003YJHQA
# 10399  ID_000H9XOP
#
# [10400 rows x 1 columns]

# %%
users5
# Out:
#         FeatureX  FeatureY      User_ID  Created At Year  createdmonth  \
# 1076           0         0  ID_5V8MKZIX                1            11
# 1183           0         0  ID_0GJ8LKKP                1            12
# 1553           0         1  ID_MVWRQYKA                1            12
# 1965           0         0  ID_L9CNOJ1K                1            11
# 2283           0         0  ID_KL7OBZXK                1             1
# ...          ...       ...          ...              ...           ...
# 319056         0         1  ID_42XELPAK                1             4
# 319098         0         0  ID_Y02FKZWI                1             3
# 319140         0         0  ID_YJCY8FF5                1             5
# 319230         0         0  ID_QDL8A9FQ                1             4
# 319247         0         1  ID_C5393PD0                1            11
#
#         Created At Day_of_month Title datetime time  datemonth  \
# ...

# %%
dataset.User_ID.nunique(), dataset[dataset['datemonth'] == 5].User_ID.nunique(),  samplesub.User_ID_Next_month_Activity.nunique()
# Out:
# (10400, 2203, 1340)

# %%
user_df = pd.merge(Selected_users, usersfinal1, on='User_ID',  how='inner')

# %%
all_activities = dataset.main_activities.unique()
month_cols = [f'datemonth_{i}' for i in [1, 2, 3, 4, 5, 11, 12]]
test_ids = samplesub.User_ID_Next_month_Activity.str.replace('_Month_5', '').unique()

activity_df = user_df[['User_ID']]

for activity in all_activities:
    _df = pd.get_dummies(
        dataset[dataset.main_activities == activity].drop(columns='main_activities').reset_index(drop=True),
        columns=['datemonth'])
    for col in month_cols:
        if col not in _df.columns:
            _df[col] = 0
        _df[col] *= _df['count']
    _df = _df.drop(columns='count')
    # accumulate the counts
    _df = _df.groupby('User_ID').sum().reset_index()
    # merge with all users
    _df = pd.merge(user_df[['User_ID']], _df, on='User_ID', how='left')
     # fill missing values with 0
    _df[month_cols] = _df[month_cols].fillna(0)
    _df.columns = _df.columns.str.replace('datemonth_', f'{activity}_month_')

    activity_df = pd.merge(activity_df, _df, on='User_ID', how='left')

# merge with users
activity_df = pd.merge(activity_df, user_df, on='User_ID', how='left')

train_df = activity_df[~activity_df.User_ID.isin(test_ids)].reset_index(drop=True)
test_df = activity_df[activity_df.User_ID.isin(test_ids)].reset_index(drop=True)

display(train_df, test_df)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [67], in <cell line: 7>()
#      21     _df[month_cols] = _df[month_cols].fillna(0)
#      22     _df.columns = _df.columns.str.replace('datemonth_', f'{activity}_month_')
# ---> 24     activity_df = pd.merge(activity_df, _df, on='User_ID', how='left')
#      26 # merge with users
#      27 activity_df = pd.merge(activity_df, user_df, on='User_ID', how='left')
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:122, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
#     107     op = _MergeOperation(
#     108         left,
# ...

# %%
from tqdm import tqdm 

new_train = pd.DataFrame()
for i in tqdm(range(len(train_df))):
    user = train_df.loc[i]
    created_month = user['createdmonth']
    if created_month < 5:
        user_dict = {}
        user_dict['User_ID'] = user['User_ID']
        for activity in all_activities:
            user_dict[f'{activity}'] = user[f'{activity}_month_{created_month}']
        next_month = [created_month+1, 1][created_month == 12]
        user_dict['Active'] = [0, 1][user[[f'{activity}_month_{next_month}' for activity in all_activities]].sum() > 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 4>()
#       1 from tqdm import tqdm
#       3 new_train = pd.DataFrame()
# ----> 4 for i in tqdm(range(len(train_df))):
#       5     user = train_df.loc[i]
#       6     created_month = user['createdmonth']
#
# NameError: name 'train_df' is not defined
